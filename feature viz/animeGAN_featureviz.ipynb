# %%
from __future__ import print_function
from PIL import Image
import random
import torch
import torchvision.utils as vutils
from torch.autograd import Variable
import torchvision.transforms

import models

# %%
#manually load netG.pth
from google.colab import files
files.upload()

# %%
model_path = 'netG.pth'
netG = models._netG_1(2, 100, 3,64, 1) # ngpu, nz, nc, ngf, n_extra_layers
netG.load_state_dict(torch.load(model_path, map_location=lambda storage, loc: storage))
print(netG)

# %% [markdown]
# ---

# %%
# %%capture
import torch
import copy
import torchvision.models as models

# https://pytorch.org/vision/stable/models.html
model = models.vgg16(pretrained=True)  #this will not pretrain it

model.eval()

# %% [markdown]
# ---
#
# https://github.com/tensorflow/lucid/wiki/Importing-Models-into-Lucid

# %%
# %tensorflow_version 1.x  #required after tf 2.0 released
import numpy as np
import tensorflow as tf

# !pip install --quiet lucid==0.2.3
# !pip install --quiet lucid
import lucid.modelzoo.vision_models as models
from lucid.misc.io import show
import lucid.optvis.objectives as objectives
import lucid.optvis.param as param
import lucid.optvis.render as render
import lucid.optvis.transform as transform
import operator

# googlenet = models.InceptionV1()
# dir(googlenet)
# googlenet.load_graphdef()
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `1.x  #required after tf 2.0 released`. This will be interpreted as: `1.x`.
#
#
# TensorFlow 1.x selected.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import files
files.upload()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import os
os.chdir("drive/My Drive/")
os.listdir()
# Out:
# ['Colab Notebooks',
#  'netG.pth',
#  'models.py',
#  '_old',
#  'neuron duality audio',
#  'Shinkai_53.pb']

# %%
from lucid.modelzoo.vision_models import Model
# dir(Model)
model = Model.load("Shinkai_53.pb")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0abc81caf913> in <module>()
#       1 from lucid.modelzoo.vision_models import Model
#       2 # dir(Model)
# ----> 3 model = Model.load("Shinkai_53.pb")
#       4
#
# /tensorflow-1.15.2/python3.7/lucid/modelzoo/vision_base.py in load(url)
#     325   def load(url):
#     326     if url.endswith(".pb"):
# --> 327       return Model.load_from_graphdef(url)
#     328     elif url.endswith(".json"):
#     329       return Model.load_from_manifest(url)
#
# /tensorflow-1.15.2/python3.7/lucid/modelzoo/vision_base.py in load_from_graphdef(graphdef_url)
#     345       return Model.load_from_metadata(graphdef_url, metadata)
#     346     else:
# ...

# %%
render.render_vis(model, "layer_name:0")

# %%
channel = lambda n: objectives.channel("mixed3a", n)
obj = channel(32)
render.render_vis(googlenet, obj)
