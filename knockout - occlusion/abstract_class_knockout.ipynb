# %% [markdown]
# Original code from:
# https://colab.research.google.com/github/pytorch/pytorch.github.io/blob/master/assets/hub/pytorch_vision_googlenet.ipynb

# %% [markdown]
# # Get output probabilities

# %%
# %%capture
import torch
import torchvision.models as models
from torchvision import transforms
import copy
from PIL import Image

# model = torch.hub.load('pytorch/vision:v0.9.0', 'googlenet', pretrained=True)
model = models.googlenet(pretrained=True)  #w/o arg, this will not pretrain it
# model = models.vgg16(pretrained=True)

model.eval() #set model in eval mode: https://stackoverflow.com/questions/60018578/what-does-model-eval-do-in-pytorch

# Download ImageNet labels
# !wget https://raw.githubusercontent.com/pytorch/hub/master/imagenet_classes.txt
with open("imagenet_classes.txt", "r") as f:
    categories = [s.strip() for s in f.readlines()]

# %%
# Download an example image from the pytorch website
import urllib
url, filename = ("https://github.com/pytorch/hub/raw/master/images/dog.jpg", "dog.jpg")
try: urllib.URLopener().retrieve(url, filename)
except: urllib.request.urlretrieve(url, filename)

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-c69e0efc-5b55-4371-b650-9d624ec95ccb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c69e0efc-5b55-4371-b650-9d624ec95ccb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving greatwhiteshark.jpg to greatwhiteshark.jpg
# Saving tigershark.jpg to tigershark.jpg
# {'greatwhiteshark.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\x0f\x12\x12\x15\x0f\x0f\x12\x0f\x15\x15\x15\x15\x0f\x0f\x15\x15\x15\x0f\x0f\x10\x10\x0f\x10\x15\x15\x16\x16\x15\x15\x15\x15\x18\x1d( \x18\x1a%\x1d\x15\x15!1!%)+...\x17\x1f383-7(-.+\x01\n\n\n\x0e\r\x0e\x17\x10\x10\x1a-% %--++++---/-+-----+------------------------+-------\xff\xc0\x00\x11\x08\x00\xb7\x01\x13\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x00\x03\x00\x03\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\xff\xc4\x00;\x10\x00\x02\x02\x01\x02\x03\x05\x05\x06\x04\x06\x03\x01\x00\x00\x00\x00\x01\x02\x11\x03\x04!\x121A\x05Qaq\x81"\x91\xa1\xb1\xc1\x06\x132b\xd1\xf0\x14R\x92\xe1#3r\x82\xa2\xf1\x16BC\x15\xff\xc4\x00\x1a\x01\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x03\x02\x04\x05\x06\xff\xc4\x00$\x11\x01\x00\x02\x02\x02\x01\x05\x00\x03\x01\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x11\x041!\x12\x13\x14AQ"a\xa1\xd1\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xf2\x8d\x890b\xb3\xf4\x8f\xcb\xaa,sk\xa1\x8d\x81t\xaa\xb2[\x04\xc4\xce\xa0+\x0b\x06I\xd2\x9d\x8a\xc1\x88\xaa\xa0\x10\x00\xd0\xd1#\x08` &\x83\xb0\x15\x85\x94\x00\x00\x00\x00\x05\x00\xc4\x000\x00\x01\xca^\\\x92\xdb\xe6H\xc4\x00\x00\x00\x00\x02\n\x00\x04P\x00\x00\x19X\x86#\x07 \x00ES@\xc0\x19\xd0D\x94*,\x04\x03\xa0\xa3\xa5 \x1d\x05\x00\x86\x14\x14D\x00:\n\x01\x00\xe8\x00C\x00(@0\x01\x00\x0c\x00@\xd0\x00\x00\x00\x00\x00\x14\x02\x18\x82\x80\x00\x01\x00\xc4\x06@\x06\x06.Hb\x19@1\r\x14 \xa0\x19B\x01\x81B\x00\x00\x03_\x16\xae-\xb5\xba\xa7[\xec\xac\xd89z\xcaO\x85uno\xcd\xf4\xfa\xfa\x98g\xc94\x88\x98o\x83\x1do3\x12\xea\x01\xab\xa4\xc9\xd1\x9bE\xc5\x9a/\x1f\xdae\xc38\xe7\xfa\x00\x035b@0\x01\x00\xc0\xa2@`P\x80`\x02\x01\x88\x00\x06 \xa0C`P\x80b\x01\x00\xc0\n\x10X\xac\xc80\x15\x81C\x1960\x18\x08\n\x86\x02\xb0\xb0\x18\x08Atl\xe3k%\xfe#\xf3_#\xb0\xce&oo+\xe1\xdf\x7f\x96\xc7\x97\x95?\xc6\x1e\xae,\x7f)u\xbb3N\xe6\xb6\xe7\xd0\xde\xd4\xe9\xdcwi\xa6\xb9\xa7\xdd\xdeo\xfd\x94\xec\xed\xd6L\xb2Q\x82~r\x9b[\xd2\xfa\xbe\x96o\xf6\xa6\x95\xcf#\x97\x1c\x17^i\x7f\xc7\x9f\xc0\xf9u\xcd4\xbe\xe1\xf5-\x8a/MK\xcc\x8c\xe9d\xec\x86\xb9qxZQ^\x89\x91\xff\x00\xe5\xcb\xab\xf4J\xfe(\xfa\xb5\xe5c\x98\xed\xf2\xad\xc4\xc9\x13\xd3@,\xe8>\xcc\xad\xdc\xab\xd5}\x0coM\x8duo\xf7\xe4>V?\xd4\xf8\x99\x7f\x1av\x06yC\x1fF\xfd\xcd\x92\xb1\xaf\xcf\xee\xa2\xfc\xaa/\xc3\xc8\xc4\x06\x7f\xe1\x9b\xe5\x1c\x9f?\xa0\xd6\x83/%\x0c\x9f\xd2\xef\xdcX\xe4\xe3\xfds<\\\xbf\x8dv#bZ\x1c\xcb\x9e9\xfa\xc2K\xe8a\x96).i\xfb\x8d#-\'\xa9g8o\x1d\xc4\x90\x81\x88\xd1\xc6\x8c\x04\x16P\xc0M\x8a\xc0` \xb0\x18\n\xc0)Y\x8ay*K\xb9\x97f\x1dO+\xee\xf9\x19[\xad\xba\xacylXY\x18\x93\xe1\xe2\xe9m\x05\x8a\xda-\x1b\x82k\xa6K\x0b"\xc7gi\xa5\xd8\x89\xb1\xb6D\xd2\xacV\x11M\xf2F|z)\xb5\xc4\xe9G\xac\x9b\xa8\xaf^\xff\x00\x05\xb9\xcd\xb2V\xbd\xcb\xba\xe3\xb5\xba\x86\x06\xc7\x18\xb7\xc9?\xa1\xb1\x8f\xeeS\xafjo\xc1p\xafK\xfd\r\x8f\xe3\x1c_\x0c1\xc1y\xc7\x89\xaf\xea\xb3\xcd~TGP\xf4S\x8b3\xdc\xb4\x1e\x92SMqp\xaeNU\xc8zm\x0e\x18=\xad\xd7Y*^\x91\xfdY\xd8\xd2\xca\x19\xa4\xa1\x93#\x8f\xe7\xe1\xb8Ex\xae\xef"\xb1\xf6c\x93k\x07\xb4\x979\xca\xa0\x97\x8e\xee\x91\xe1\xcb\x9ao>^\xecXb\x91\xe1\x8e:\xb5\x1a\xb95\xc5\xec\xa4\x93m\xd2n\xbc\x15\'\xdc\x87\x8bQi\xca\x1e\xca\xb7\x1b\xbfi\xb5\xcfs+\xec\xf8\xc1\xae9\xac\x8f\xba6\xe0\x9f\x8c\xba\xfa{\xcd\x88\xe8\xd4]\xbbW\xbf\r\xb6\xa3\xd7\x93\xfc<\xf9\x1e\x7fTC\xd3\xa6\xa6\x1csoc{\x0e\x9a+\xda\x9b\xe2~v\x93\xf3\xeag\xd2\xe9\\\xdf\x0cv\\\xdb\xee^\'K?e\xe3\x94\x165|=e\xba\x94\xbc<\x11\xc5\xb2\xba\xad!\xe5\xb3\xf6\x94\\\xaa4\xdfr\xdf\x87\xcd.C\x84\xe7=\x94x\xbc\xa1\x7f\x04\x8e\xa6\x9bC\x83\x04-bNV\xdb\xfeE\xbdU/\x06\x8d\xff\x00\xbe\xc94\xd65\x8dRN\xb8\x1a\\\xb9U\xf2\xfe\xe4\xf7\'\xea\x17\xd3\x1fo7/\xbc\xe9\x860[\xfbSU\xcb\x9d\'\xcf\xd1\x11\xfcdc\xd1\xcb\xc5T\x17\xa6\xdfC\xb3\xa6\x9ce9G3\xb6\xb8\xa2\x9dr~\xbc\x8ev\xb7J\x958\xf5\xafA\x19\'~W\xd3\x1fL1\xd7\xdb\xff\x00-W|\xa79?\x9a\xf9\x19e\x97\x8dW\x13\x8f\x82U\x1fZ\xe7\xea`\xc1\xa3s\x92I>\xe3\xb9\xa5\xec ...
#  'tigershark.jpg': b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\n\x07\x08\x16\x15\x15\x18\x15\x15\x15\x18\x18\x18\x18\x1a\x18\x19\x18\x19\x1a\x1a\x18\x18\x18\x18\x18\x1a\x18\x1a\x1a\x18\x1a\x18\x19\x1c!.%\x1c\x1e+!\x18\x18&8&+/1555\x1a$;@;4?.451\x01\x0c\x0c\x0c\x10\x0f\x10\x1e\x12\x12\x1e4,$+44414444444444444444444444444444444444444444444444\xff\xc0\x00\x11\x08\x00\xb0\x01\x1e\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1b\x00\x00\x02\x03\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x02\x03\x01\x04\x05\x00\x06\x07\xff\xc4\x007\x10\x00\x01\x03\x02\x04\x04\x03\x06\x06\x02\x02\x03\x00\x00\x00\x00\x01\x00\x02\x11\x03!\x04\x121A\x05Qaq\x81\x91\xb1\x06\x13"\xa1\xc1\xf02BR\xd1\xe1\xf1\x14b3r\x15\x82\xa2\xff\xc4\x00\x1a\x01\x00\x03\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\xff\xc4\x00*\x11\x00\x02\x02\x02\x01\x04\x01\x03\x03\x05\x00\x00\x00\x00\x00\x00\x00\x01\x02\x11\x03\x12!\x131AQ\x04"2a\x81\xa1\xb1\x05\x14#q\x91\xff\xda\x00\x0c\x03\x01\x00\x02\x11\x03\x11\x00?\x00\xc8\x0fR*$)\x0b\xea\x0f\x92qC\xf3\xa8\x94\x01\xcae2h`r\xe0\xe4\xb9R\x1c\x80\xa1\x99\x97fK.Q\x991j;?T9\x92\xe5q(\x1e\xa3s\xa8/\xea\x93\x99qr,5\x1c\xe7\xa0=\x12\xa5\x10Hz\xd1%\xc9E\xc5\x1b\x8aS\x8a\x96\\Q\xcer\x179A\xee\x94\\T\xb6h\xa2Iz\xec\xddR\x8b\x90fY\xech\xa2Y\xcf\xd5\x17\xbc\xbe\xaa\xa6u\xd9\xd1b\xd0\xb2\xfa\x84\xeaR\x9c\xe8J\xcc\xa32M\xd9J449IzHz\xe0\xe4\xec\xadF\x07&\x87\xaa\xe1\x1b\\\x9ad\xca%\x8c\xd2\xa0=(9I*\xec\x8dG\x8a\xa7E!\xc9\x12\x89\xaeE\x89\xc4ndB\xac%\x17\xee,W>\xa1:\x94X\xb5\xb1\x98\xaa\xcdu\xc3r\xf3\x00\x92>d\x9f\x9a\xaa\xf7\xa9\xa8\xe5R\xa9*%*5\x84MRT\x87!\x95\xd2\xb50\xa0\xf3\xa9\xce\x95+\xb3"\xc5\xa8\xd9])Y\x94\xe6E\x85\r\x94I\x19\x94\xe7N\xc3Q\x92\xbb2Ve\xd9\x91a\xa8d\xa1\x94%\xc8K\x92\xb1\xa8\x8c\xcc\xb8=(\x94%\xc9YZ\x8e\xce\x96\xf7 .B\xe7$\xd8\xd4Ns\x90\x17(q@J\xcd\xb3T\x88s\x94\x12\xa0\x94\x04\xa8l\xd1 \xcb\xd4J\tQ*lt0\x15\xd2\x82Q\x02\x9a\n\x08"\x08\x11\x05HL\x94@\xa1R\x15\x12\x11*AA*ALT\x1edR\x94J\x89N\xc5\xa8\xe9\x95\xc6\xa0\x88\x81\xde\xe99\x94\x17\xa5\xb0\xf5\x08\x94\x87\xa2/BJ\x86\xec\xb4\xa8\xd2qQ(%L\xad\xac\xe6\xa0\xa5t\xa1\x95\x12\x8b\n\x0f2\xec\xc8%t\xa2\xc7A\xca\x89C+\x89E\x85\x05+\xa5\x0c\xae\x94XPD\xa1\xcc\xb9A\tX\xd19\x94fPP\x94\xaci\x12\\\x84\xa8%AR\xd9Tq(I\\T\x14\x99H\x12\x80\xa2*\n\x86Z\x05B\x95\nFr \x85HM\x03\x18\xa4\x14\x00\xa9V\x842WJ\x19])\xd94\x14\xa8\x95\x12\xa0\x94XPY\x97fA*\tE\x95A\x17!.BJ\x82Rli\x12J\x12W\x12\x80\x95\r\x94\x91\xa8\xb9H\x0b\xa1nr\x10\xa5p\x0b\xa10!r(]\x95\x01`\xaeS\x0b\xa1 \xb2\x14\xc2\xe8S\x08\x0b$\x05\x7f\x05\xc2*\xd6iu6f\r0L\xb4_\x94\x13\x7f\x05E\x81{\xdfa\xe1\xb4^\xe25y\x1e\x01\xad\x8fR\xb2\xcf\x91\xc26\x8d0\xc1Nz\xb3\xc2\xe20\xaea\xca\xf6\x96\xb8j\x08 \xfc\xd5w\x05\xf5\x9cw\x0eev\xc3\xd8\x0bv<\xbf\xeav\xf0^\x1b\x8d\xfb8\xfa2\xf6K\xd9\xff\x00\xd3{\x81\xa8\xea\x16X\xfeTg\xc4\xb8f\xd9>4\xa1\xca\xe5\x1em\xc1\x01O,Jp[\xb3\x14\xc1\x94%\x11\n!IH\x12\x84\xa3!\x0c$R\x06\x14#\x85\x04 ,\x05!L.\x84\x0e\xc9\x95\xcb\xa1r\x00\x99\\\x84)N\xc5GJ\x82\xb8\xa8(\xb1\x9d*\t\\W%c8\x94%IP\x81\xa0IBJ\x92\x80\x95,\xb4n5\xaar\xa7\xb5\x88\x855\xd5G\x98\xe6V\x1c\xb7E\x916\xae\x16`\xc1\xb7-\xc7\xee\xa7.R\x012\x0f\xe1w>\x87\xaa\x87*\x95?\xd0\xb5\xf5+\x8f\xea\'"\x9c\xaa\xe0\xa0y.4!iF]DS\xc8\xa3"\xb9\xee\x94\xfb\x94\xa8:\x88\xa5\x91vUm\xd4O$#\n\xe3\xa0H{\xafb\x03W\xbb\xf6&\xb6Z.\xb01P\xc4\xf5kJ\xf1tp\xaes\xc3\x00%\xc4\xc0\x1dW\xbc\xe1\xce\xa3\x84`c\x9e\x1c\xff\x00\xc4\xf6\xb6\t\xccyG-<\x17\x17\xca\x92\xd7_\'o\xc3\xfb\xf6\xf0\x91\xb3U\xef|@\x81\xe4\x14?\x0b?\x9cF\xf3\xb2\xc4\xc4{D\xe2l#\x97n\x80\xfa\xc1X\xd8\x9fh\x0c\xbb\xe1\x01\xbb\x92I$\xede\xc1\xa9\xe8<\xab\xc0^\xd3{=HK\xe8<f\x9f\x89\x8d\x12\x0c\xee#E\xe4_\x83x\xd5\x84y\x0fU\xad\x88\xc7\xd4\x7f\xc3\x9c\xde\xe04d\x07\xcbn\xab:\xab\t\xb9\x17\x9bu\xe7\x13\xea\xba#\x96QUg4\xa0\xa4\xee\xa8\xaa\xea$k\x03\xff\x00f\xc7\x9c\xa1k\x01\x9f\x8cLi\x0f7\xe51\x1f5k\xdc\t\xbf-\xaf\xdd5\xb4\x85\xbe\xed\xd0*\xebI\x93\xd3H\xcc,<\xbdT\neh\xbf\x98\x13\xf7\xc9,5\xc7Q\tu\xa45\x04R\xf7eI\xa4U\xcfpQ\n\x06 ...

# %%
def get_output(model, input_image):
    # input_image = Image.open(input)
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    input_tensor = preprocess(input_image)
    input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

    # move the input and model to GPU for speed if available
    if torch.cuda.is_available():
        input_batch = input_batch.to('cuda')
        model.to('cuda')

    with torch.no_grad():
        output = model(input_batch)
    return output
    # Tensor of shape 1000, with confidence scores over Imagenet's 1000 classes
    # print(output[0])  # The output has unnormalized scores. To get probabilities, you can run a softmax on it.

def output_probs(model, input_image):
    output = get_output(model, input_image)
    probabilities = torch.nn.functional.softmax(output[0], dim=0)
    return probabilities

def get_top_categories(probabilities, categories):
  top5_prob, top5_catid = torch.topk(probabilities, 5)
  for i in range(top5_prob.size(0)):
      print(categories[top5_catid[i]], top5_prob[i].item())

# %%
input_image_1 = Image.open('tigershark.jpg')
input_image_2 = Image.open('greatwhiteshark.jpg')

probs_tiger_shark = output_probs(model, input_image_1)
probs_great_white_shark = output_probs(model, input_image_2)

# %%
get_top_categories(probs_tiger_shark, categories)
# Out:
# tiger shark 0.9285188317298889
# gar 0.008483723737299442
# great white shark 0.006604191847145557
# sturgeon 0.005556200165301561
# axolotl 0.0019637865480035543

# %%
get_top_categories(probs_great_white_shark, categories)
# Out:
# great white shark 0.6037811636924744
# tiger shark 0.35362929105758667
# hammerhead 0.02359415590763092
# sturgeon 0.001169938943348825
# killer whale 0.0006463401368819177

# %% [markdown]
# ---

# %% [markdown]
# # Compare probabilities after 1 neuron knockout

# %%
#knockout conv 3
new_model_1 = copy.deepcopy(model)
new_model_1.conv3.conv.weight.data = new_model_1.conv3.conv.weight.data * 0

new_probs_tiger_shark = output_probs(new_model_1, input_image_1)

def compare_probs(probabilities, new_probabilities, categories):
    top5_prob, top5_catid = torch.topk(probabilities, 5)
    new_top5_prob, new_top5_catid = torch.topk(new_probabilities, 5)
    for i in range(new_top5_prob.size(0)):
        row = ['before:', categories[top5_catid[i]], round(top5_prob[i].item(), 5), 'after:', categories[new_top5_catid[i]], round(new_top5_prob[i].item(), 5)]
        print("{: >10} {: >15} {: >10} {: >10} {: >15} {: >10}".format(*row))

compare_probs(probs_tiger_shark, new_probs_tiger_shark, categories)
# Out:
#    before:     tiger shark    0.92852     after:    space heater     0.4274
#    before:             gar    0.00848     after:     loudspeaker    0.40686
#    before: great white shark     0.0066     after:   window screen    0.08127
#    before:        sturgeon    0.00556     after:        strainer    0.04828
#    before:         axolotl    0.00196     after:           radio    0.00625

# %%
# Find avg change in probability for all classes

def Average(lst):
    return sum(lst) / len(lst)

prob_change = [probs_tiger_shark[i] - new_probs_tiger_shark[i] for i in range(len(probs_tiger_shark))]

print(Average(prob_change[5:]))
# Out:
# tensor(-0.0009, device='cuda:0')

# %%
# get top 3 most frequent changes in prob
from collections import Counter
c = Counter(prob_change)
c.most_common(3)
# Out:
# [(tensor(0.0003, device='cuda:0'), 1),
#  (tensor(0.0002, device='cuda:0'), 1),
#  (tensor(0.0066, device='cuda:0'), 1)]

# %%
# remove outliers then get mean

# %% [markdown]
# ---

# %% [markdown]
# # Knockout neuron communities

# %% [markdown]
# **KNOCKOUT LAYERS**
#
# The following shows knocking out which layers cause the greatest change in the predicted probability for Tiger Shark. The output of this cell shows the new predicted probability for Tiger Shark, so the layer which has the lowest probability suggests that layer is very important for predicting Tiger Shark.

# %%
#loop through every layer and find top 10 layers in which knocking out that layer causes the biggest change
torch.cuda.empty_cache()

layer_scores = {}
new_model_2 = copy.deepcopy(model)
for layer_name, layer in new_model_2.named_modules():
    if type(layer) == torch.nn.modules.conv.Conv2d:
        temp_weightMatrix = layer.weight.data.detach().clone() #old values
        layer.weight.data = layer.weight.data * 0  #modify using call by reference 
        new_probabilities = output_probs(new_model_2, input_image_1)
        layer_scores[layer_name] = new_probabilities[3].item()
        layer.weight.data = temp_weightMatrix # restore old values

sorted(layer_scores.items(), key=lambda item: item[1])

# %% [markdown]
# **KNOCKOUT FILTERS**
#
# Next, try knocking out individual filters within an important layer to further pinpoint which filters in it are important.

# %%
def knockout_layer(layer_name, model, input_image):
    new_model = copy.deepcopy(model)
    for name_to_check, layer in new_model.named_modules():
        if name_to_check == layer_name:
            break
    filter_scores = {}
    for filter_ind in range(layer.weight.data.shape[0]):  #layer.weight.data.shape  #[# filters, # channels, filter_height, filter_width]
        temp_weightMatrix = layer.weight.data[filter_ind].detach().clone() #old values
        layer.weight.data[filter_ind] = layer.weight.data[filter_ind] * 0  #modify using call by reference 
        new_probabilities = output_probs(new_model, input_image_1)
        filter_scores[filter_ind] = new_probabilities[3].item()
        layer.weight.data[filter_ind] = temp_weightMatrix # restore old values

    # Show bottom 10 and top 10 weights
    return sorted(filter_scores.items(), key=lambda item: item[1])

knockout_layer('conv3.conv', model, input_image_1)
# knockout_layer('inception3a.branch2.1.conv', model, input_image_1)
# knockout_layer('features.26')  #VGG

# %% [markdown]
# **KNOCKOUT RANDOM COMBOS OF FILTERS**
#
# Instead of knocking out one filter, try combos of filters. Try random percentages of a layer, then avg different combos of the same %

# %%
import random

def knockout_layer_perc(layer_name):
    new_model = copy.deepcopy(model)
    for name_to_check, layer in new_model.named_modules():
        if name_to_check == layer_name:
            break
    filter_scores = {}
    for perc in range(1,10):
        perc /= 10
        temp_weightMatrix = layer.weight.data.detach().clone() #old values
        total_num_filters = layer.weight.data.shape[0]
        knockedout_filts = random.sample(range(0,total_num_filters), round(perc*total_num_filters))  #no repeats
        for filter_ind in knockedout_filts:
            layer.weight.data[filter_ind] = layer.weight.data[filter_ind] * 0  #modify using call by reference 
        new_output = new_model(input_batch)  # run modified model
        new_probabilities = torch.nn.functional.softmax(new_output[0], dim=0)
        filter_scores[perc] = new_probabilities[3].item()
        layer.weight.data = temp_weightMatrix # restore old values

    # Show bottom 10 and top 10 weights
    return sorted(filter_scores.items(), key=lambda item: item[1])

# knockout_layer('conv3.conv')
knockout_layer_perc('inception3a.branch2.1.conv')
# Out:
# [(0.9, 0.0006269084988161922),
#  (0.7, 0.038260217756032944),
#  (0.8, 0.04518599808216095),
#  (0.6, 0.13788191974163055),
#  (0.5, 0.5507573485374451),
#  (0.4, 0.6387174725532532),
#  (0.2, 0.761429488658905),
#  (0.3, 0.8238069415092468),
#  (0.1, 0.8852053880691528)]

# %% [markdown]
# ---
#
# Get probabilities for classes in Abstract Class vs Others after knockout

# %%
# Abstract class of sharks. 3: tiger shark
abstract_class = [2, 3, 4]

# %%
for i in abstract_class:
    row = [categories[i], 'before:', probs_tiger_shark[i], 'after:', new_probs_tiger_shark[i]]
    print("{: >10} {: >10} {: >10} {: >10}".format(*row))
# Out:
#    before: 1.5476764758659556e-07     after: 1.5476764758659556e-07
#    before: 9.497205155639676e-08     after: 9.497205155639676e-08
#    before: 4.6568541733904567e-07     after: 4.6568541733904567e-07
